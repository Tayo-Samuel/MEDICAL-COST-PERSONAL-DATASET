# %% [markdown]
# **MEDICAL COST PERSONAL DATASET**

# %%
## LIBRARIES TO USE:
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


## LOADING DATASET:
insurance_data =pd.read_csv('/content/insurance.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-52b97896e92f> in <cell line: 0>()
#       7
#       8 ## LOADING DATASET:
# ----> 9 insurance_data =pd.read_csv('/content/insurance.csv')
#
# ...

# %%
insurance_data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
## BASIC ANALYSIS:

#Top 5 rows of the data:
insurance_data.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# last 5 rows of the dataset:
insurance_data.tail(5)
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
#checking for number of columns:
insurance_data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
# checking for number of rows and columns:
insurance_data.shape
# Out:
# (1338, 7)

# %%
#checking for some info about the data:
insurance_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# checking for missing values:
insurance_data.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# checking for duplicated values:
insurance_data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Length: 1338, dtype: bool

# %%
# checking for outliers:
sns.scatterplot(insurance_data['charges'])
# Out:
# <Axes: ylabel='charges'>

# %%
## STATISTICAL MEASURES OF THE DATA:

# stastistical description of the data:
insurance_data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# visual distribution of age value:
plt.figure(figsize =(6,6))
sns.histplot(data = insurance_data['age'])
plt.title('Age distribution')
# Out:
# Text(0.5, 1.0, 'Age distribution')

# %%
# visual count of gender column:
plt.figure(figsize =(6,6))
sns.countplot(x ='sex',data = insurance_data)
plt.title('sex distribution')
# Out:
# Text(0.5, 1.0, 'sex distribution')

# %%
insurance_data.value_counts('sex')
# Out:
# sex
# male      676
# female    662
# dtype: int64

# %%
# visual distribution of BMI:
plt.figure(figsize =(6,6))
sns.histplot(data = insurance_data['bmi'])
plt.title('bmi distribution')
# Out:
# Text(0.5, 1.0, 'bmi distribution')

# %%
# visual count of children column:
plt.figure(figsize =(6,6))
sns.countplot(x ='children',data = insurance_data)
plt.title('children distribution')
# Out:
# Text(0.5, 1.0, 'children distribution')

# %%
# visual showing  count of smokers:
plt.figure(figsize =(6,6))
sns.countplot(x ='smoker',data = insurance_data)
plt.title('count of smoker')
# Out:
# Text(0.5, 1.0, 'smoker distribution')

# %%
# visual showing count of region:
plt.figure(figsize =(6,6))
sns.countplot(x ='region',data = insurance_data)
plt.title('count of region')
# Out:
# Text(0.5, 1.0, 'count of region')

# %%
# visual showing the distribution of charges:
plt.figure(figsize =(6,6))
sns.histplot(data = insurance_data['charges'])
plt.title('charges distribution')
# Out:
# Text(0.5, 1.0, 'charges distribution')

# %%
## DATA ENCODING:
##Encoding categorical features: sex column, children column,region column.

# encoding sex column:
sex_encoding = pd.get_dummies(insurance_data,columns = ['sex'],drop_first=True)

# %%
sex_encoding
# Out:
#       age     bmi  children smoker     region      charges  sex_male
# 0      19  27.900         0    yes  southwest  16884.92400         0
# 1      18  33.770         1     no  southeast   1725.55230         1
# 2      28  33.000         3     no  southeast   4449.46200         1
# 3      33  22.705         0     no  northwest  21984.47061         1
# 4      32  28.880         0     no  northwest   3866.85520         1
# ...   ...     ...       ...    ...        ...          ...       ...
# 1333   50  30.970         3     no  northwest  10600.54830         1
# 1334   18  31.920         0     no  northeast   2205.98080         0
# 1335   18  36.850         0     no  southeast   1629.83350         0
# 1336   21  25.800         0     no  southwest   2007.94500         0
# 1337   61  29.070         0    yes  northwest  29141.36030         0
#
# [1338 rows x 7 columns]

# %%
# encoding children column:
region_encode =pd.get_dummies(insurance_data,columns = ['region'],drop_first=True)

# %%
region_encode
# Out:
#       age     sex     bmi  children smoker      charges  region_northwest  \
# 0      19  female  27.900         0    yes  16884.92400                 0
# 1      18    male  33.770         1     no   1725.55230                 0
# 2      28    male  33.000         3     no   4449.46200                 0
# 3      33    male  22.705         0     no  21984.47061                 1
# 4      32    male  28.880         0     no   3866.85520                 1
# ...   ...     ...     ...       ...    ...          ...               ...
# 1333   50    male  30.970         3     no  10600.54830                 1
# 1334   18  female  31.920         0     no   2205.98080                 0
# 1335   18  female  36.850         0     no   1629.83350                 0
# 1336   21  female  25.800         0     no   2007.94500                 0
# 1337   61  female  29.070         0    yes  29141.36030                 1
#
#       region_southeast  region_southwest
# ...

# %%
child_encode = pd.get_dummies(insurance_data,columns = ['children'],drop_first=True)

# %%
child_encode
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9c05a96befe6> in <cell line: 0>()
# ----> 1 child_encode
#
# NameError: name 'child_encode' is not defined

# %%
# FURTHER ANALYSIS

# WHAT IS THE MAXIMUM CHARGES:
max_charges = insurance_data['charges'].max()
print(max_charges)
# Out:
# 63770.42801

# %%
# WHAT IS THE MINIMUM CHARGES:
min_charges = insurance_data['charges'].min()
min_charges
# Out:
# 1121.8739

# %%
# WHAT IS THE AVERAGE CHARGES:
Avg_charges = insurance_data['charges'].mean()
Avg_charges
# Out:
# 13270.422265141257

# %%
# WHAT IS THE SUM OF CHARGES:
sum_charges = insurance_data['charges'].sum()

# %%
sum_charges
# Out:
# 17755824.990759

# %%
# WHAT IS THE MAXIMUM CHARGES BY AGE
max_charges_age =insurance_data.groupby('charges').max()['age']

# %%
max_charges_age
# Out:
# charges
# 1121.87390     18
# 1131.50660     18
# 1135.94070     18
# 1136.39940     18
# 1137.01100     18
#                ..
# 55135.40209    33
# 58571.07448    31
# 60021.39897    52
# 62592.87309    45
# 63770.42801    54
# Name: age, Length: 1337, dtype: int64

# %%
max_charges_age.tail(1)
# Out:
# charges
# 63770.42801    54
# Name: age, dtype: int64

# %%
# WHAT IS THE MAXIMUM CHARGES BY REGION:
max_charges_region =insurance_data.groupby('charges').max()['region']

# %%
max_charges_region
# Out:
# charges
# 1121.87390     southeast
# 1131.50660     southeast
# 1135.94070     southeast
# 1136.39940     southeast
# 1137.01100     southeast
#                  ...
# 55135.40209    northwest
# 58571.07448    northeast
# 60021.39897    northwest
# 62592.87309    southeast
# 63770.42801    southeast
# Name: region, Length: 1337, dtype: object

# %%
max_charges_region.tail(1)
# Out:
# charges
# 63770.42801    southeast
# Name: region, dtype: object
